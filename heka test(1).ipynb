# %%
#import needed modules
import heka_reader as hr           #heka reader for reading the heka files
import numpy as np                 #numpy for using arrays (needed for further analysis)
import matplotlib.pyplot as plt    #pyplot for plotting data

# %%
#Reading the data from heka file
bundle=hr.Bundle('Zelle1_1705_18Uhr54.dat')

# %%
#selecting a trace. Numbers allow it to select different groups,series, sweeps and traces. not all numbers have to be given
trace=bundle.pul[0][0][1][0]

# %%
#reading a series of data from the file. Numbers allow selection as above, all numbers are needed. An error will rise, when the wished trace is not there
data=bundle.data[0,1,0,0]
plt.plot(data)

# %%
data=bundle.data[0,2,0,0]
plt.plot(data)

# %%
data=bundle.data[0,3,0,0]
plt.plot(data)

# %%
data=bundle.data[0,4,0,0]
plt.plot(data)

# %%
data=bundle.data[0,5,0,0]
plt.plot(data)

# %%
data=bundle.data[0,6,0,0]
plt.plot(data)

# %%
#selecting another sweep
data=bundle.data[0,6,1,0]
plt.plot(data)

# %%
#selecting another trace
data=bundle.data[0,5,1,1]
plt.plot(data)

# %%
#shows information that is saved within the selected trace
trace
# Out:
# TraceRecord(
#     Mark = 0
#     Label = 'I-mon'
#     TraceCount = 1
#     Data = 23256
#     DataPoints = 5750
#     InternalSolution = 0
#     AverageCount = 1
#     LeakCount = 2
#     LeakTraces = 1
#     DataKind = 9
#     RecordingMode = b'\x03'
#     AmplIndex = b'\x00'
#     DataFormat = b'\x00'
#     DataAbscissa = b'\x01'
#     DataScaler = 6.248648082363805e-13
#     TimeOffset = 0.0
#     ZeroData = -5.184154705149496e-11
#     YUnit = 'A'
#     XInterval = 2e-05
#     XStart = 0.005
#     XUnit = 's'
#     YRange = 2.0479375e-08
#     YOffset = 0.0
#     Bandwidth = 2873.478855663455
#     PipetteResistance = 3108830.582813804
#     CellPotential = 0.0
#     SealResistance = 22493007299.159313
#     CSlow = 1.3155200736206325e-11
#     GSeries = 1.6089259682347503e-07
#     RsValue = 2669130.241561099
#     GLeak = 0.0
#     MConductance = 9.888418434918631e-10
#     LinkDAChannel = 1
#     ValidYrange = b'\x01'
#     AdcMode = b'\x01'
#     AdcChannel = 6
# ...

# %%
#reading a specific entry from the data
data[1]
# Out:
# -6.332923270174431e-11
